# %%
import pandas as pd
import json
import os

# --- Configuration ---
INPUT_FILE = 'transactions.txt'
OUTPUT_FILE = 'transactions_processed.csv'
# ---------------------

def prepare_data_for_snowflake(input_path, output_path):
    """Loads JSON data, cleans types, sorts chronologically, and saves to CSV."""
    print(f"Loading data from {input_path}...")
    
    # Load data line by line from the text file
    data = []
    try:
        with open(input_path, 'r') as f:
            for line in f:
                # Handle potential empty lines or malformed JSON gracefully
                if line.strip():
                    data.append(json.loads(line))
    except FileNotFoundError:
        print(f"Error: The file '{input_path}' was not found. Please create it.")
        return
    
    if not data:
        print("Error: The input file is empty or contains no valid JSON.")
        return

    df_raw = pd.DataFrame(data)

    # Renaming and standardizing critical columns
    df_raw.rename(columns={
        'accountNumber': 'ACCOUNT_ID',
        'transactionDateTime': 'TRANSACTION_TS',
        'transactionAmount': 'AMOUNT',
        'merchantName': 'MERCHANTNAME',
        'cardPresent': 'CARD_PRESENT' # Standardize the column name
    }, inplace=True)

    # Type Conversion (Senior DS Focus: Ensure data integrity)
    df_raw['TRANSACTION_TS'] = pd.to_datetime(df_raw['TRANSACTION_TS'])
    df_raw['AMOUNT'] = df_raw['AMOUNT'].astype(float)
    
    # Sort data chronologically - ESSENTIAL for accurate window function calculations
    df_raw.sort_values(by='TRANSACTION_TS', inplace=True)
    
    # Select only the relevant columns for the raw table to keep it clean
    raw_cols = ['ACCOUNT_ID', 'TRANSACTION_TS', 'AMOUNT', 'MERCHANTNAME', 'CARD_PRESENT',
                'merchantCategoryCode', 'posEntryMode', 'posConditionCode']
    
    # Save the cleaned, ordered data to CSV
    df_raw[raw_cols].to_csv(output_path, index=False)
    print(f"Successfully processed {len(df_raw)} records and saved to {output_path}")

# %%
prepare_data_for_snowflake(INPUT_FILE, OUTPUT_FILE)
# Out:
# Loading data from transactions.txt...
# Successfully processed 786363 records and saved to transactions_processed.csv

# %%
pip install snowflake-snowpark-python
# Out:
# Requirement already satisfied: snowflake-snowpark-python in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.42.0)
# Requirement already satisfied: setuptools>=40.6.0 in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from snowflake-snowpark-python) (65.5.0)
# Requirement already satisfied: wheel in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-snowpark-python) (0.45.1)
# Requirement already satisfied: snowflake-connector-python<5.0.0,>=3.17.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-snowpark-python) (4.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-snowpark-python) (4.15.0)
# Requirement already satisfied: pyyaml in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-snowpark-python) (6.0.2)
# Requirement already satisfied: cloudpickle!=2.1.0,!=2.2.0,<=3.1.1,>=1.6.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-snowpark-python) (3.1.1)
# Requirement already satisfied: protobuf<6.32,>=3.20 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-snowpark-python) (6.31.1)
# Requirement already satisfied: python-dateutil in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-snowpark-python) (2.9.0.post0)
# Requirement already satisfied: tzlocal in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-snowpark-python) (5.3.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (1.5.1)
# Requirement already satisfied: cryptography>=3.1.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (46.0.3)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (25.3.0)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (2.10.1)
# Requirement already satisfied: pytz in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (2025.2)
# Requirement already satisfied: requests<3.0.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (2.32.5)
# Requirement already satisfied: packaging in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (2025.8.3)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (3.19.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (4.4.0)
# Requirement already satisfied: tomlkit in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (0.13.3)
# Requirement already satisfied: boto3>=1.24 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (1.40.64)
# Requirement already satisfied: botocore>=1.24 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (1.40.64)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=3.1.0->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (2.0.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (2.5.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3>=1.24->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3>=1.24->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (0.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil->snowflake-snowpark-python) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=2.0.0->cryptography>=3.1.0->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python) (2.23)
# Requirement already satisfied: tzdata in c:\users\nandi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tzlocal->snowflake-snowpark-python) (2025.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\nandi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from snowflake.snowpark.session import Session
from sklearn.ensemble import IsolationForest
import joblib

# --- 1. Define Snowflake Connection Parameters ---
# NOTE: Replace these placeholders with your actual Snowflake credentials
SNOWFLAKE_CONN_PARAMS = {
    "account" :"MBYCHCU-LPC98923",
    "user" : "NANZ",
    "password" : "XXXXXXXXXXXXXXXX",
    "warehouse": "COMPUTE_WH",
    "database" :"FINANCIAL_ANALYTICS",
    "schema": "FRAUD_DETECTION"
}
# Out:
# Successfully connected to Snowflake.
# Training on 773107 records after dropping 13256 initial rows.
# Isolation Forest Model trained successfully.
# Model saved locally as 'isolation_forest_model_v1.joblib'

# %%
# --- 2. Define Features for Training ---
MODEL_FEATURES = [
    'AMOUNT', 
    'AMT_1HR_ACCT', 
    'COUNT_24HR_ACCT', 
    'HOUR_OF_DAY',
    'NEW_MERCHANT_COUNT_7D', 
    'AMT_Z_SCORE_30D', 
    'CARD_PRESENT_RATIO_7D'
]

# --- 3. Connect and Pull Data ---
try:
    session = Session.builder.configs(SNOWFLAKE_CONN_PARAMS).create()
    print("Successfully connected to Snowflake.")

    # Pull data from the V_MODEL_FEATURES view
    sql_query = f"SELECT {', '.join(MODEL_FEATURES)} FROM V_MODEL_FEATURES"
    
    # Use Snowpark to get the data into a Pandas DataFrame
    snowpark_df = session.sql(sql_query)
    df_train = snowpark_df.to_pandas()
    
    session.close()

except Exception as e:
    print(f"Error connecting to Snowflake or pulling data: {e}")
    # You would typically have a more robust error handling mechanism
    exit()

# %%
# --- 4. Data Pre-processing (Handling NaNs) ---
# Isolation Forest cannot handle NaN values. NaNs arise from initial transactions
# where the window functions (like Z-score) don't have enough history yet.
X_train = df_train[MODEL_FEATURES].dropna() 
print(f"Training on {len(X_train)} records after dropping {len(df_train) - len(X_train)} initial rows.")

# --- 5. Train the Isolation Forest Model ---
# Concept: The contamination parameter. We set this to the expected fraction of anomalies (0.1%).
# Tuning this value later is key to reducing your 20% false positive rate.
iso_forest = IsolationForest(
    contamination=0.001, # 0.1% expected fraud rate
    random_state=42, 
    n_estimators=100
)

iso_forest.fit(X_train)
print("Isolation Forest Model trained successfully.")

# --- 6. Save the Model ---
MODEL_FILENAME = 'isolation_forest_model_v1.joblib'
joblib.dump(iso_forest, MODEL_FILENAME)
print(f"Model saved locally as '{MODEL_FILENAME}'")
